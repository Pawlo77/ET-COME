# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
run_id = 0

import os
from utils import RESULTS_DIR

run_dir = os.path.join(RESULTS_DIR, f"run_{run_id}")
results_df = None
for file in os.listdir(run_dir):
    if file.endswith(".pkl"):
        dataset_name, smote_name, model_name, option, take = os.path.basename(os.path.splitext(file)[0]).split("__")
        cur_df = pd.read_json(os.path.join(run_dir, file), orient="records", lines=True)
        cur_df["dataset_name"] = dataset_name
        cur_df["smote_name"] = smote_name
        cur_df["model_name"] = model_name
        cur_df["option"] = option
        cur_df["take"] = take
        cur_df["run_id"] = run_id
        
        for stage in ["train", "test"]:
            for key in ["accuracy", "f1", "precision", "recall", "roc_auc"]:
                cur_df[f"{stage}_{key}"] = cur_df[stage].map(lambda x: x[key])
        cur_df = cur_df.drop(columns=["train", "test"])

        if results_df is None:
            results_df = cur_df
        else:
            results_df = pd.concat([results_df, cur_df], ignore_index=True)

# %%
results_df
# Out:
#                                      params  \
# 0                          {'max_depth': 5}
# 1                         {'max_depth': 10}
# 2                         {'max_depth': 20}
# 3      {'max_depth': 5, 'n_estimators': 10}
# 4      {'max_depth': 5, 'n_estimators': 25}
# ...                                     ...
# 2449  {'max_depth': 20, 'n_estimators': 10}
# 2450  {'max_depth': 20, 'n_estimators': 50}
# 2451  {'max_depth': 10, 'n_estimators': 50}
# 2452  {'max_depth': 20, 'n_estimators': 25}
# 2453  {'max_depth': 20, 'n_estimators': 50}
#
#                                                   train  \
# 0     {'accuracy': 0.9075747794000001, 'f1': 0.90947...
# 1     {'accuracy': 0.9599741769000001, 'f1': 0.96080...
# 2     {'accuracy': 0.972993329, 'f1': 0.9730252552, ...
# 3     {'accuracy': 0.9779175919, 'f1': 0.9780717873,...
# 4     {'accuracy': 0.9798914384, 'f1': 0.9800514013,...
# ...                                                 ...
# 2449  {'accuracy': 0.96125, 'f1': 0.9613947696, 'rec...
# 2450  {'accuracy': 0.9937500000000001, 'f1': 0.99372...
# 2451  {'accuracy': 1.0, 'f1': 1.0, 'recall': 1.0, 'p...
# 2452  {'accuracy': 0.99, 'f1': 0.9899749373000001, '...
# 2453  {'accuracy': 1.0, 'f1': 1.0, 'recall': 1.0, 'p...
#
#                                                    test  \
# 0     {'accuracy': 0.8444790047, 'f1': 0.4382022472,...
# 1     {'accuracy': 0.8724727838, 'f1': 0.48750000000...
# 2     {'accuracy': 0.8833592535, 'f1': 0.48275862070...
# 3     {'accuracy': 0.9519572954000001, 'f1': 0.76923...
# 4     {'accuracy': 0.9537366548, 'f1': 0.7796610169,...
# ...                                                 ...
# 2449  {'accuracy': 0.7272727273, 'f1': 0.66666666670...
# 2450  {'accuracy': 0.7272727273, 'f1': 0.66666666670...
# 2451  {'accuracy': 0.7402597403000001, 'f1': 0.67741...
# 2452  {'accuracy': 0.7272727273, 'f1': 0.66666666670...
# 2453  {'accuracy': 0.7402597403000001, 'f1': 0.67741...
#
#                dataset_name smote_name              model_name      option  \
# 0                  satimage      SMOTE  DecisionTreeClassifier  no_bagging
# 1                  satimage      SMOTE  DecisionTreeClassifier  no_bagging
# 2                  satimage      SMOTE  DecisionTreeClassifier  no_bagging
# 3            optical_digits      SMOTE  RandomForestClassifier  no_bagging
# 4            optical_digits      SMOTE  RandomForestClassifier  no_bagging
# ...                     ...        ...                     ...         ...
# 2449  Pima Indians Diabetes      SMOTE           XGBClassifier     bagging
# 2450  Pima Indians Diabetes      SMOTE           XGBClassifier     bagging
# 2451  Pima Indians Diabetes      SMOTE           XGBClassifier     bagging
# 2452  Pima Indians Diabetes      SMOTE           XGBClassifier     bagging
# 2453  Pima Indians Diabetes      SMOTE           XGBClassifier     bagging
#
#      take  run_id  train_accuracy  train_f1  train_precision  train_recall  \
# 0       4       0        0.907575  0.909474         0.891161      0.928556
# 1       4       0        0.959974  0.960809         0.941176      0.981278
# 2       4       0        0.972993  0.973025         0.971876      0.974177
# 3       2       0        0.977918  0.978072         0.971290      0.984949
# 4       2       0        0.979891  0.980051         0.972317      0.987910
# ...   ...     ...             ...       ...              ...           ...
# 2449    2       0        0.961250  0.961395         0.957816      0.965000
# 2450    2       0        0.993750  0.993726         0.997481      0.990000
# 2451    2       0        1.000000  1.000000         1.000000      1.000000
# 2452    2       0        0.990000  0.989975         0.992462      0.987500
# 2453    2       0        1.000000  1.000000         1.000000      1.000000
#
#       train_roc_auc  test_accuracy   test_f1  test_precision  test_recall  \
# 0          0.945944       0.844479  0.438202        0.336207     0.629032
# 1          0.978447       0.872473  0.487500        0.397959     0.629032
# 2          0.994535       0.883359  0.482759        0.421687     0.564516
# 3          0.992021       0.951957  0.769231        0.737705     0.803571
# 4          0.995735       0.953737  0.779661        0.741935     0.821429
# ...             ...            ...       ...             ...          ...
# 2449       0.995687       0.727273  0.666667        0.583333     0.777778
# 2450       0.999862       0.727273  0.666667        0.583333     0.777778
# 2451       1.000000       0.740260  0.677419        0.600000     0.777778
# 2452       0.999669       0.727273  0.666667        0.583333     0.777778
# 2453       1.000000       0.740260  0.677419        0.600000     0.777778
#
#       test_roc_auc
# 0         0.869830
# 1         0.808062
# 2         0.779066
# 3         0.975385
# 4         0.978314
# ...            ...
# 2449      0.792593
# 2450      0.803704
# 2451      0.785185
# 2452      0.792593
# 2453      0.785185
#
# [2454 rows x 19 columns]
